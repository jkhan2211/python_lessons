# %%
# Task 1 - While loop
""" number = 1
while number<5:
    print(number)
    number +=1 """
counter = 26
while counter > 15:
    print(counter)
    counter -=2
print("While loop has ended")

# %%
# Task 2 - For loop
""" cars = ['Audi', 'VW', 'Jaguar','Mini']
for x in cars:
    print(x) """

numbers = [1,2,3,4,5,6]
for num in numbers:
    print(num)
    if num == 7:
        break
else:
    print("Number not found!")

# %%
# Task 3 - Nested loop
numbers = [1,2,3]
letters = ['a','b','c','d']
for number in numbers:
    print(number)
    for letter in letters:
        print(number, letter)

# %%
# Task 4 - Functions
def print_name(fname, lname, age):
    print("My name is: " + fname+ " "+lname + " and my age is: "+ str(age))

print_name("Junaid","Khan", 30)
# Out:
# My name is: Junaid Khan and my age is: 30

# %%
# Task 6 - Return statement
def about_me():
    name="Junaid"
    age=30
    id=2
    return [name, age, id]

listresult = about_me()
print(listresult)
# Out:
# ['Junaid', 30, 2]
